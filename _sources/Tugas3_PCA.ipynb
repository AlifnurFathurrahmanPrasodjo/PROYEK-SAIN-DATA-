# %% [markdown]
# # TUGAS 3 (PCA)

# %% [markdown]
# ## Get Data Sepal-Width from Posgresql Elephant

# %%
import psycopg2
import pandas as pd

# Buat koneksi ke PostgreSQL.
conn = psycopg2.connect(database="dkhkulnr", user="dkhkulnr", password="mV-fN3EtQn4-mAda8Kq61x87QBNko5Ou", host="floppy.db.elephantsql.com", port="5432")


# Buat cursor untuk menjalankan query SQL.
cur = conn.cursor()

# Jalankan query SQL.
cur.execute("SELECT ROW_NUMBER() OVER () as id, sepalwidth FROM iris;")

# Ambil hasil query.
hasil_query = cur.fetchall()

df = pd.DataFrame(hasil_query, columns=["id", "sepalwidth"])
df_postEle_sepalwidth = pd.DataFrame(hasil_query, columns=["id", "sepalwidth"])
print(df)

# Tutup cursor dan koneksi.
cur.close()
conn.close()
# Out:
#       id sepalwidth
# 0      1        3.5
# 1      2          3
# 2      3        3.2
# 3      4        3.1
# 4      5        3.6
# ..   ...        ...
# 145  146          3
# 146  147        2.5
# 147  148          3
# 148  149        3.4
# 149  150          3
#
# [150 rows x 2 columns]

# %% [markdown]
# ## Get Data sepal-length from Posgresql Elephant

# %%
import psycopg2
import pandas as pd

# Buat koneksi ke PostgreSQL.
conn = psycopg2.connect(database="dkhkulnr", user="dkhkulnr", password="mV-fN3EtQn4-mAda8Kq61x87QBNko5Ou", host="floppy.db.elephantsql.com", port="5432")


# Buat cursor untuk menjalankan query SQL.
cur = conn.cursor()

# Jalankan query SQL.
cur.execute("SELECT ROW_NUMBER() OVER () as id, sepallength FROM iris;")

# Ambil hasil query.
hasil_query = cur.fetchall()

df = pd.DataFrame(hasil_query, columns=["id", "sepallength"])
df_postEle_sepallength = pd.DataFrame(hasil_query, columns=["id", "sepallength"])
print(df)

# Tutup cursor dan koneksi.
cur.close()
conn.close()
# Out:
#       id sepallength
# 0      1         5.1
# 1      2         4.9
# 2      3         4.7
# 3      4         4.6
# 4      5           5
# ..   ...         ...
# 145  146         6.7
# 146  147         6.3
# 147  148         6.5
# 148  149         6.2
# 149  150         5.9
#
# [150 rows x 2 columns]

# %% [markdown]
# ## Get Data Petal-Width + Class from CSV

# %%
# source data
dataset_url = "/content/drive/MyDrive/PROYEK SAIN DATA C/Iris-_1_.csv"

# %%
import pandas as pd
#read in the data using pandas
df_csv_petalwidth = pd.read_csv(dataset_url)
#check data has been read in properly
df_csv_petalwidth
# Out:
#       Id  petalwidth           class
# 0      1         0.2     Iris-setosa
# 1      2         0.2     Iris-setosa
# 2      3         0.2     Iris-setosa
# 3      4         0.2     Iris-setosa
# 4      5         0.2     Iris-setosa
# ..   ...         ...             ...
# 145  146         2.3  Iris-virginica
# 146  147         1.9  Iris-virginica
# 147  148         2.0  Iris-virginica
# 148  149         2.3  Iris-virginica
# 149  150         1.8  Iris-virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# ## Get Data Petal-Length from mysql hosting

# %%
# !pip install pymysql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 4.0 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
import pymysql
import pandas as pd
mydb = pymysql.connect(
  db="petal_length", user="admin",passwd="ZDFHM60q",host="mysql-114539-0.cloudclusters.net", port=10002,autocommit=True)
cur = mydb.cursor()
cur.execute("SELECT * FROM iris")
data = cur.fetchall()
column_names = ["id","petal_l"]
df_sqlhosting_petallength = pd.DataFrame(data, columns=column_names)
print(df_sqlhosting_petallength)
# Out:
#       id petal_l
# 0      1     1.4
# 1      2     1.4
# 2      3     1.3
# 3      4     1.5
# 4      5     1.4
# ..   ...     ...
# 145  146     5.2
# 146  147     5.0
# 147  148     5.2
# 148  149     5.4
# 149  150     5.1
#
# [150 rows x 2 columns]

# %% [markdown]
# ## Gabung data

# %%
# merge df
result = pd.concat([df_postEle_sepallength, df_postEle_sepalwidth,df_sqlhosting_petallength, df_csv_petalwidth], axis=1)
#result = pd.merge(df_postLocal,df_sqlServer, how="inner", on=["id", "id"])
result
# Out:
#       id sepallength   id sepalwidth   id petal_l   Id  petalwidth  \
# 0      1         5.1    1        3.5    1     1.4    1         0.2
# 1      2         4.9    2          3    2     1.4    2         0.2
# 2      3         4.7    3        3.2    3     1.3    3         0.2
# 3      4         4.6    4        3.1    4     1.5    4         0.2
# 4      5           5    5        3.6    5     1.4    5         0.2
# ..   ...         ...  ...        ...  ...     ...  ...         ...
# 145  146         6.7  146          3  146     5.2  146         2.3
# 146  147         6.3  147        2.5  147     5.0  147         1.9
# 147  148         6.5  148          3  148     5.2  148         2.0
# 148  149         6.2  149        3.4  149     5.4  149         2.3
# 149  150         5.9  150          3  150     5.1  150         1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 9 columns]

# %%
result.drop(result.columns[[0,2,4,6]],axis=1,inplace=True)
result
# Out:
#     sepallength sepalwidth petal_l  petalwidth           class
# 0           5.1        3.5     1.4         0.2     Iris-setosa
# 1           4.9          3     1.4         0.2     Iris-setosa
# 2           4.7        3.2     1.3         0.2     Iris-setosa
# 3           4.6        3.1     1.5         0.2     Iris-setosa
# 4             5        3.6     1.4         0.2     Iris-setosa
# ..          ...        ...     ...         ...             ...
# 145         6.7          3     5.2         2.3  Iris-virginica
# 146         6.3        2.5     5.0         1.9  Iris-virginica
# 147         6.5          3     5.2         2.0  Iris-virginica
# 148         6.2        3.4     5.4         2.3  Iris-virginica
# 149         5.9          3     5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Proses PCA

# %% [markdown]
# Anda perlu menginstal pustaka berikut dari python Anda.

# %%
# !pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn) (1.1.1)

# %% [markdown]
# Langkah 1: Mengimpor perpustakaan

# %%
# importing required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X = result.values[:, :4]
Y = result.values[:, 4]
print(X)
# Out:
# [['5.1' '3.5' Decimal('1.4') 0.2]
#  ['4.9' '3' Decimal('1.4') 0.2]
#  ['4.7' '3.2' Decimal('1.3') 0.2]
#  ['4.6' '3.1' Decimal('1.5') 0.2]
#  ['5' '3.6' Decimal('1.4') 0.2]
#  ['5.4' '3.9' Decimal('1.7') 0.4]
#  ['4.6' '3.4' Decimal('1.4') 0.3]
#  ['5' '3.4' Decimal('1.5') 0.2]
#  ['4.4' '2.9' Decimal('1.4') 0.2]
#  ['4.9' '3.1' Decimal('1.5') 0.1]
#  ['5.4' '3.7' Decimal('1.5') 0.2]
#  ['4.8' '3.4' Decimal('1.6') 0.2]
#  ['4.8' '3' Decimal('1.4') 0.1]
#  ['4.3' '3' Decimal('1.1') 0.1]
#  ['5.8' '4' Decimal('1.2') 0.2]
#  ['5.7' '4.4' Decimal('1.5') 0.4]
#  ['5.4' '3.9' Decimal('1.3') 0.4]
#  ['5.1' '3.5' Decimal('1.4') 0.3]
#  ['5.7' '3.8' Decimal('1.7') 0.3]
#  ['5.1' '3.8' Decimal('1.5') 0.3]
#  ['5.4' '3.4' Decimal('1.7') 0.2]
#  ['5.1' '3.7' Decimal('1.5') 0.4]
#  ['4.6' '3.6' Decimal('1.0') 0.2]
#  ['5.1' '3.3' Decimal('1.7') 0.5]
#  ['4.8' '3.4' Decimal('1.9') 0.2]
#  ['5' '3' Decimal('1.6') 0.2]
#  ['5' '3.4' Decimal('1.6') 0.4]
#  ['5.2' '3.5' Decimal('1.5') 0.2]
#  ['5.2' '3.4' Decimal('1.4') 0.2]
#  ['4.7' '3.2' Decimal('1.6') 0.2]
#  ['4.8' '3.1' Decimal('1.6') 0.2]
#  ['5.4' '3.4' Decimal('1.5') 0.4]
#  ['5.2' '4.1' Decimal('1.5') 0.1]
#  ['5.5' '4.2' Decimal('1.4') 0.2]
#  ['4.9' '3.1' Decimal('1.5') 0.1]
#  ['5' '3.2' Decimal('1.2') 0.2]
#  ['5.5' '3.5' Decimal('1.3') 0.2]
#  ['4.9' '3.1' Decimal('1.5') 0.1]
#  ['4.4' '3' Decimal('1.3') 0.2]
#  ['5.1' '3.4' Decimal('1.5') 0.2]
#  ['5' '3.5' Decimal('1.3') 0.3]
#  ['4.5' '2.3' Decimal('1.3') 0.3]
#  ['4.4' '3.2' Decimal('1.3') 0.2]
#  ['5' '3.5' Decimal('1.6') 0.6]
#  ['5.1' '3.8' Decimal('1.9') 0.4]
#  ['4.8' '3' Decimal('1.4') 0.3]
#  ['5.1' '3.8' Decimal('1.6') 0.2]
#  ['4.6' '3.2' Decimal('1.4') 0.2]
#  ['5.3' '3.7' Decimal('1.5') 0.2]
#  ['5' '3.3' Decimal('1.4') 0.2]
#  ['7' '3.2' Decimal('4.7') 1.4]
#  ['6.4' '3.2' Decimal('4.5') 1.5]
#  ['6.9' '3.1' Decimal('4.9') 1.5]
#  ['5.5' '2.3' Decimal('4.0') 1.3]
#  ['6.5' '2.8' Decimal('4.6') 1.5]
#  ['5.7' '2.8' Decimal('4.5') 1.3]
#  ['6.3' '3.3' Decimal('4.7') 1.6]
#  ['4.9' '2.4' Decimal('3.3') 1.0]
#  ['6.6' '2.9' Decimal('4.6') 1.3]
#  ['5.2' '2.7' Decimal('3.9') 1.4]
#  ['5' '2' Decimal('3.5') 1.0]
#  ['5.9' '3' Decimal('4.2') 1.5]
#  ['6' '2.2' Decimal('4.0') 1.0]
#  ['6.1' '2.9' Decimal('4.7') 1.4]
#  ['5.6' '2.9' Decimal('3.6') 1.3]
#  ['6.7' '3.1' Decimal('4.4') 1.4]
#  ['5.6' '3' Decimal('4.5') 1.5]
#  ['5.8' '2.7' Decimal('4.1') 1.0]
#  ['6.2' '2.2' Decimal('4.5') 1.5]
#  ['5.6' '2.5' Decimal('3.9') 1.1]
#  ['5.9' '3.2' Decimal('4.8') 1.8]
#  ['6.1' '2.8' Decimal('4.0') 1.3]
#  ['6.3' '2.5' Decimal('4.9') 1.5]
#  ['6.1' '2.8' Decimal('4.7') 1.2]
#  ['6.4' '2.9' Decimal('4.3') 1.3]
#  ['6.6' '3' Decimal('4.4') 1.4]
#  ['6.8' '2.8' Decimal('4.8') 1.4]
#  ['6.7' '3' Decimal('5.0') 1.7]
#  ['6' '2.9' Decimal('4.5') 1.5]
#  ['5.7' '2.6' Decimal('3.5') 1.0]
#  ['5.5' '2.4' Decimal('3.8') 1.1]
#  ['5.5' '2.4' Decimal('3.7') 1.0]
#  ['5.8' '2.7' Decimal('3.9') 1.2]
#  ['6' '2.7' Decimal('5.1') 1.6]
#  ['5.4' '3' Decimal('4.5') 1.5]
#  ['6' '3.4' Decimal('4.5') 1.6]
#  ['6.7' '3.1' Decimal('4.7') 1.5]
#  ['6.3' '2.3' Decimal('4.4') 1.3]
#  ['5.6' '3' Decimal('4.1') 1.3]
#  ['5.5' '2.5' Decimal('4.0') 1.3]
#  ['5.5' '2.6' Decimal('4.4') 1.2]
#  ['6.1' '3' Decimal('4.6') 1.4]
#  ['5.8' '2.6' Decimal('4.0') 1.2]
#  ['5' '2.3' Decimal('3.3') 1.0]
#  ['5.6' '2.7' Decimal('4.2') 1.3]
#  ['5.7' '3' Decimal('4.2') 1.2]
#  ['5.7' '2.9' Decimal('4.2') 1.3]
#  ['6.2' '2.9' Decimal('4.3') 1.3]
#  ['5.1' '2.5' Decimal('3.0') 1.1]
#  ['5.7' '2.8' Decimal('4.1') 1.3]
#  ['6.3' '3.3' Decimal('6.0') 2.5]
#  ['5.8' '2.7' Decimal('5.1') 1.9]
#  ['7.1' '3' Decimal('5.9') 2.1]
#  ['6.3' '2.9' Decimal('5.6') 1.8]
#  ['6.5' '3' Decimal('5.8') 2.2]
#  ['7.6' '3' Decimal('6.6') 2.1]
#  ['4.9' '2.5' Decimal('4.5') 1.7]
#  ['7.3' '2.9' Decimal('6.3') 1.8]
#  ['6.7' '2.5' Decimal('5.8') 1.8]
#  ['7.2' '3.6' Decimal('6.1') 2.5]
#  ['6.5' '3.2' Decimal('5.1') 2.0]
#  ['6.4' '2.7' Decimal('5.3') 1.9]
#  ['6.8' '3' Decimal('5.5') 2.1]
#  ['5.7' '2.5' Decimal('5.0') 2.0]
#  ['5.8' '2.8' Decimal('5.1') 2.4]
#  ['6.4' '3.2' Decimal('5.3') 2.3]
#  ['6.5' '3' Decimal('5.5') 1.8]
#  ['7.7' '3.8' Decimal('6.7') 2.2]
#  ['7.7' '2.6' Decimal('6.9') 2.3]
#  ['6' '2.2' Decimal('5.0') 1.5]
#  ['6.9' '3.2' Decimal('5.7') 2.3]
#  ['5.6' '2.8' Decimal('4.9') 2.0]
#  ['7.7' '2.8' Decimal('6.7') 2.0]
#  ['6.3' '2.7' Decimal('4.9') 1.8]
#  ['6.7' '3.3' Decimal('5.7') 2.1]
#  ['7.2' '3.2' Decimal('6.0') 1.8]
#  ['6.2' '2.8' Decimal('4.8') 1.8]
#  ['6.1' '3' Decimal('4.9') 1.8]
#  ['6.4' '2.8' Decimal('5.6') 2.1]
#  ['7.2' '3' Decimal('5.8') 1.6]
#  ['7.4' '2.8' Decimal('6.1') 1.9]
#  ['7.9' '3.8' Decimal('6.4') 2.0]
#  ['6.4' '2.8' Decimal('5.6') 2.2]
#  ['6.3' '2.8' Decimal('5.1') 1.5]
#  ['6.1' '2.6' Decimal('5.6') 1.4]
#  ['7.7' '3' Decimal('6.1') 2.3]
#  ['6.3' '3.4' Decimal('5.6') 2.4]
#  ['6.4' '3.1' Decimal('5.5') 1.8]
#  ['6' '3' Decimal('4.8') 1.8]
#  ['6.9' '3.1' Decimal('5.4') 2.1]
#  ['6.7' '3.1' Decimal('5.6') 2.4]
#  ['6.9' '3.1' Decimal('5.1') 2.3]
#  ['5.8' '2.7' Decimal('5.1') 1.9]
#  ['6.8' '3.2' Decimal('5.9') 2.3]
#  ['6.7' '3.3' Decimal('5.7') 2.5]
#  ['6.7' '3' Decimal('5.2') 2.3]
#  ['6.3' '2.5' Decimal('5.0') 1.9]
#  ['6.5' '3' Decimal('5.2') 2.0]
#  ['6.2' '3.4' Decimal('5.4') 2.3]
#  ['5.9' '3' Decimal('5.1') 1.8]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( 
    X, Y, test_size = 0.2, random_state = 100)

# %%
# Applying PCA function on training
# and testing set of X component
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)

X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

explained_variance = pca.explained_variance_ratio_

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print (" DecisionTree Accuracy : ",
    accuracy_score(y_test,y_pred)*100)
# Out:
#  DecisionTree Accuracy :  90.0

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
print (" KNN Accuracy : ",
    accuracy_score(y_test,y_pred)*100)
# Out:
#  KNN Accuracy :  100.0
